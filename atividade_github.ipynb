# %% [markdown]
# <a href="https://colab.research.google.com/github/jborim/jborim/blob/main/atividade_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": [],
      "include_colab_link": True
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {
        "id": "view-in-github",
        "colab_type": "text"
      },
      "source": [
        "<a href=\"https://colab.research.google.com/github/VielF/ColabProjects/blob/main/Exemplo_Morfologia.ipynb\" target=\"_parent\"><img src=\"https://colab.research.google.com/assets/colab-badge.svg\" alt=\"Open In Colab\"/></a>"
      ]
    },
    {
      "cell_type": "markdown",
      "source": [
        "Universidade do Vale do Itajaí<br>\n",
        "Escola do Mar, Ciência e Tecnologia<br>\n",
        "Professor Felipe Viel\n",
        "\n",
        "Morfologia-M3\n",
        "\n",
        "Júlia Borim dos Reis\n",
      ],
      "metadata": {
        "id": "hs7F3RjrUjCH"
      }
    },
    {
      "cell_type": "code",
      "source":[
        "#Para iniciar devemos importar as bibliotecas cv2 para exibir a imagem\n ",
        "#E importar a biblioteca numpy para execução das matrizes\n ",
        "import cv2\n",
        "import numpy as np\n",
        "from google.colab.patches import cv2_imshow\n",
        "\n"
        "#Em img = cv2.imread vai ler a imagem.\n ",
        "#A abertura \opening\ vai limpar os pequenos fragmentos da imagem, os pontinhos que estao fora do \j\,\n",
        "# no fechamento \closing\  vai preencher o buraquinhos dentro do \j\ ",
        "#Definimos altura e largura da imagem\n",
        "#A kernel gera uma matriz 5 por 5 preenchida com o numero 1, \np.uint8\ é o tipo de dado\n",
        "img = cv2.imread('j.png',0)\n",
        "img_opening = cv2.imread('j_ruido.png',0)\n",
        "img_closing = cv2.imread('j_furos.png',0)\n",
        "altura, largura = img.shape\n",
        "kernel = np.ones((5,5),np.uint8)\n",
        "print(kernel)"
        "\n"
         "#A erosão vai resudir o volume de pixels e sera identificado por erode\n",
         "#A dilatação vai aumentar a imagem, podendo preencher pequenos buracos na imagem",
         "#Ambas erosão e dilatação são aplicadas duas vezes indentificamos como\iterations=2\ \n",
        "erosion = cv2.erode(img,kernel,iterations = 2)\n",
        "dilation = cv2.dilate(img,kernel,iterations = 2)"
        "\n"
        "#Usando as operações morfológicas gradiente,abertura e fechamento "
        "#Cada imagem recebe um tratamento diferente\n",
        "#Gradiente vai gerar o contorno\n ",
        "#Abertura é erosão seguida da dilatação\n",
        "#Fechamento é a dilatação em seguida da erosão\n",
        "gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)\n",
        "opening = cv2.morphologyEx(img_opening, cv2.MORPH_OPEN, kernel)\n",
        "closing = cv2.morphologyEx(img_closing, cv2.MORPH_CLOSE, kernel)"
        "\n"
        "#Imprime cada imagem separadamente\n",
        "cv2_imshow(img)\n",
        "cv2_imshow(erosion)\n",
        "cv2_imshow(dilation)\n",
        "cv2_imshow(opening)\n",
        "cv2_imshow(closing)\n",
        "cv2_imshow(gradient)"
      ],

    }
  ]
}
# Out:
# {'nbformat': 4,
#  'nbformat_minor': 0,
#  'metadata': {'colab': {'provenance': [], 'include_colab_link': True},
#   'kernelspec': {'name': 'python3', 'display_name': 'Python 3'},
#   'language_info': {'name': 'python'}},
#  'cells': [{'cell_type': 'markdown',
#    'metadata': {'id': 'view-in-github', 'colab_type': 'text'},
#    'source': ['<a href="https://colab.research.google.com/github/VielF/ColabProjects/blob/main/Exemplo_Morfologia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>']},
#   {'cell_type': 'markdown',
#    'source': ['Universidade do Vale do Itajaí<br>\n',
#     'Escola do Mar, Ciência e Tecnologia<br>\n',
#     'Professor Felipe Viel\n',
#     '\n',
#     'Morfologia-M3\n',
#     '\n',
#     'Júlia Borim dos Reis\n'],
#    'metadata': {'id': 'hs7F3RjrUjCH'}},
#   {'cell_type': 'code',
#    'source': ['#Para iniciar devemos importar as bibliotecas cv2 para exibir a imagem\n ',
# ...
